# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dataset/raw/zomato.csv")

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
df.sample(5)
# Out:
#                                                      url  \
# 6744   https://www.zomato.com/bangalore/zaica-dine-wi...
# 50213  https://www.zomato.com/bangalore/litti-house-b...
# 42     https://www.zomato.com/bangalore/mcdonalds-ban...
# 569    https://www.zomato.com/bangalore/peppy-peppers...
# 7811   https://www.zomato.com/bangalore/chef-bakers-b...
#
#                                                  address               name  \
# 6744   125, 1st Floor, Mahadevanpura Post, Brookefiel...  Zaica Dine & Wine
# 50213  Opposite to AECS Layout, Kundalahalli Main Roa...        Litti House
# 42     2466, Bhaskar Grand Tower, 24th Cross, Opposit...         McDonald's
# 569    942, 3rd Floor, 21st Main Road, 2nd Stage, Ban...      Peppy Peppers
# 7811      188, Kundalahalli, ITPL Main Road, Brookefield       Chef Baker's
#
#       online_order book_table    rate  votes  \
# 6744           Yes        Yes   3.8/5    818
# 50213          Yes         No  3.9 /5    200
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 51717
# Columns : 17

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.describe(include="object")
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/the-nest-the-...  Delivery Only
# freq                                                    1            128
#
#                    name online_order book_table   rate         phone location  \
# count             51717        51717      51717  43942         50509    51696
# unique             8792            2          2     64         14926       93
# top     Cafe Coffee Day          Yes         No    NEW  080 43334321      BTM
# freq                 96        30444      45268   2208           216     5124
#
#           rest_type dish_liked      cuisines approx_cost(for two people)  \
# count         51490      23639         51672                       51371
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                                132
# url                             22562402
# address                          6043024
# name                             3338630
# online_order                     2668011
# book_table                       2644016
# rate                             2637353
# votes                             413736
# phone                            3498238
# location                         3137826
# rest_type                        3135143
# dish_liked                       3579758
# cuisines                         3761922
# approx_cost(for two people)      2696168
# reviews_list                   495059116
# menu_item                       32186854
# listed_in(type)                  2955431
# listed_in(city)                  3196826
# dtype: int64

# %%
df.memory_usage(deep=True).sum() / 1024**2
# Out:
# np.float64(566.0196170806885)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %% [markdown]
# ## Initial Observations
#
# - Dataset contains 51,717 restaurant records.
# - The dataset has 17 columns.
# - Ratings are stored as text instead of numeric values.
# - Approximate cost contains commas and is stored as text.
# - Missing values are present in multiple columns.
# - Categorical columns such as online_order and book_table contain Yes/No values.
# - Further data cleaning is required before analysis.
